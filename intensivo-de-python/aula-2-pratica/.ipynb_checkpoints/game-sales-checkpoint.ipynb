# %%
import requests
response = requests.get('https://docs.google.com/spreadsheets/d/1wGaAwmA01qFMCNRdtJCUH2V4wapxTk0HvuVSO_MAD0I/edit?usp=sharing')
assert response.status_code == 200, 'Wrong status code'
print(response.content)
# Out:
# ------------------------------------
# AssertionErrorTraceback (most recent call last)
# <ipython-input-63-ec3aaa392703> in <module>
#       1 import requests
#       2 response = requests.get('https://doc-00-6o-sheets.googleusercontent.com/export/sfomnm8gu8obeok0nobjhk4qu8/f566jocecbpjvssk000ng0bkhk/1619832710000/105768068263350496130/105768068263350496130/1wGaAwmA01qFMCNRdtJCUH2V4wapxTk0HvuVSO_MAD0I?format=csv&id=1wGaAwmA01qFMCNRdtJCUH2V4wapxTk0HvuVSO_MAD0I&gid=1277673405&dat=AMvwolYOydoszTKMl-Fi7EY1V9CxnhO6h6zDsXpxNhZT2N9livyNAMUHnHQnG6ixBo5D3E6SZ2B_CmOqB4zppAhvADtqk63ARjMjpXw93hEgSwWjkD8uXtnZ-7zpdE0yhCOT_SP3o5hnL3CPLPnayb7gtDzm9m4yvAK04biWdOP5gnrhbSVC31MKtqlpxcD1HlyU5rD2NcSmH5H1kvP7L7y7_NYCLu3rLGCCmcf1rNOJyMHSYmoJ4OTHzgmlw_z87O9FpMmwo5cjQAmghGqfB_Bcj2a-ALBt5iMlsQN62geoC9x6yahh5Tc_sYJjClIwAGRz8GvO8hENy-ho8jqbLiRJDKDwGm_BE1MvgMdkZ9cL_aUtTEHQwKRBP4pg2l3DReECWxKH__Dfh0r_aVjTt2ePjyLK8J8fgeCLsxJGhzfij_1Cocs9fjek3XaBe34J_QgGjnp7cyLEgfQpWC8LovXFq3wJcdG3H-99c2GVQTgdB7BawU9ZldgsCy8YerMGhLRAeEraAMlc1HURuM7XdgchcbTtg0X6GNJU8GQhM1d6p-LlwAbsC5Wb0aZlksv4U9P_oooC7FvIeIq5yl1h6GVU1dpX3VCXSEL8SkCa9MATgOaSugywogJ3WfZ8ViHzqvgL_CtR3JUsisSD_IgWXZQTozl6NON6u9BABcr6a8Jef9aJe6FDcxXLtXbYMFz6KgA9sE4aqY0XGppbg3xHckyWqOJJQpY')
# ----> 3 assert response.status_code == 200, 'Wrong status code'
#       4 print(response.content)
#
# AssertionError: Wrong status code

# %%
import pandas as panda

dados = panda.read_csv("vendas.csv")
# dados = panda.drop(["Unnamed: 0"], axis=1)
display(dados)
# Out:
#   Carimbo de data/hora Quem preenche este formulário?  \
# 0  30/04/2021 21:37:50                        Gabriel
# 1  30/04/2021 21:38:15                        Gabriel
#
#   Nome (somente primeiro nome)     Bairro  Pedido [Art.Smash]  \
# 0                     Phillipe  Esplanada                 NaN
# 1                         Dora   Alvorada                 NaN
#
#    Pedido [Art.Cheese]  Pedido [Art.Linguiça]  Pedido [Art.Frango]  \
# 0                  3.0                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
#
#    Pedido [Art.Bacon]  Pedido [Art.Special]  ...  Pedido [Pastel G]  \
# 0                 NaN                   NaN  ...                NaN
# 1                 NaN                   NaN  ...                1.0
#
#    Pedido [Porçãao de Batata]  Pedido [Milkshake Chocolate]  \
# 0                         1.0                           NaN
# 1                         NaN                           NaN
#
#    Pedido [Milkshake Morango]  Pedido [Refri 200ml]  Pedido [Refri Lata]  \
# 0                         NaN                   3.0                  NaN
# 1                         NaN                   NaN                  NaN
#
#    Forma de Pagamento  Valor do pedido ( somente numeros )  \
# 0               PIX 🔑                                   63
# 1          Dinheiro 💵                                   10
#
#   Taxa de Entrega (Somente Numeros, Se não tiver taxa, digite zero)  \
# 0                                                  3
# 1                                                  0
#
#    Observação
# 0         NaN
# 1         NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# ## **Tratamento de datas**

# %%
dados = dados.rename(columns={'Carimbo de data/hora' : 'Data'})
dados['Data'] = dados['Data'].str.slice_replace(10, 19, '')
dados['Data'] = panda.to_datetime(dados['Data'], format="%d/%m/%Y")
print(dados.info())
display(dados)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 22 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Data                                                               2 non-null      datetime64[ns]
#  1   Quem preenche este formulário?                                     2 non-null      object
#  2   Nome (somente primeiro nome)                                       2 non-null      object
#  3   Bairro                                                             2 non-null      object
#  4   Pedido [Art.Smash]                                                 0 non-null      float64
#  5   Pedido [Art.Cheese]                                                1 non-null      float64
#  6   Pedido [Art.Linguiça]                                              0 non-null      float64
#  7   Pedido [Art.Frango]                                                0 non-null      float64
#  8   Pedido [Art.Bacon]                                                 0 non-null      float64
#  9   Pedido [Art.Special]                                               0 non-null      float64
#  10  Pedido [Art.Double]                                                0 non-null      float64
#  11  Pedido [Pastel P]                                                  0 non-null      float64
#  12  Pedido [Pastel G]                                                  1 non-null      float64
#  13  Pedido [Porçãao de Batata]                                         1 non-null      float64
#  14  Pedido [Milkshake Chocolate]                                       0 non-null      float64
#  15  Pedido [Milkshake Morango]                                         0 non-null      float64
#  16  Pedido [Refri 200ml]                                               1 non-null      float64
#  17  Pedido [Refri Lata]                                                0 non-null      float64
#  18  Forma de Pagamento                                                 2 non-null      object
#  19  Valor do pedido ( somente numeros )                                2 non-null      int64
#  20  Taxa de Entrega (Somente Numeros, Se não tiver taxa, digite zero)  2 non-null      int64
#  21  Observação                                                         0 non-null      float64
# dtypes: datetime64[ns](1), float64(15), int64(2), object(4)
# memory usage: 480.0+ bytes
# None
#         Data Quem preenche este formulário? Nome (somente primeiro nome)  \
# 0 2021-04-30                        Gabriel                     Phillipe
# 1 2021-04-30                        Gabriel                         Dora
#
#       Bairro  Pedido [Art.Smash]  Pedido [Art.Cheese]  Pedido [Art.Linguiça]  \
# 0  Esplanada                 NaN                  3.0                    NaN
# 1   Alvorada                 NaN                  NaN                    NaN
#
#    Pedido [Art.Frango]  Pedido [Art.Bacon]  Pedido [Art.Special]  ...  \
# 0                  NaN                 NaN                   NaN  ...
# 1                  NaN                 NaN                   NaN  ...
#
#    Pedido [Pastel G]  Pedido [Porçãao de Batata]  \
# 0                NaN                         1.0
# 1                1.0                         NaN
#
#    Pedido [Milkshake Chocolate]  Pedido [Milkshake Morango]  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
#
#    Pedido [Refri 200ml]  Pedido [Refri Lata]  Forma de Pagamento  \
# 0                   3.0                  NaN               PIX 🔑
# 1                   NaN                  NaN          Dinheiro 💵
#
#    Valor do pedido ( somente numeros )  \
# 0                                   63
# 1                                   10
#
#   Taxa de Entrega (Somente Numeros, Se não tiver taxa, digite zero)  \
# 0                                                  3
# 1                                                  0
#
#    Observação
# 0         NaN
# 1         NaN
#
# [2 rows x 22 columns]

# %%
dados.columns = dados.columns.str.replace("[", '')
dados.columns = dados.columns.str.replace("]", '')
display(dados)
dados = dados.rename(columns={
    'Pedido Art.Smash' : 'Art.Smash',
    'Pedido Art.Cheese' : 'Art.Cheese',
    'Pedido Art.Linguiça' : 'Art.Linguiça',
    'Pedido Art.Frango' : 'Art.Frango',
    'Pedido Art.Bacon' : 'Art.Bacon',
    'Pedido Art.Special' : 'Art.Special',
    'Pedido Art.Double' : 'Art.Double',
    'Pedido Pastel P' : 'Pastel P',
    'Pedido Pastel G' : 'Pastel G',
    'Pedido Porçãao de Batata' : 'Porçãao de Batata',
    'Pedido Milkshake Chocolate' : 'Milkshake Chocolate',
    'Pedido Milkshake Morango' : 'Milkshake Morango',
    'Pedido Refri 200ml' : 'Refri 200ml',
    'Pedido Refri Lata' : 'Refri Lata',
})
display(dados)
# Out:
# <ipython-input-61-dfaa441cd117>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   dados.columns = dados.columns.str.replace("[", '')
# <ipython-input-61-dfaa441cd117>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   dados.columns = dados.columns.str.replace("]", '')
#         Data Quem preenche este formulário? Nome (somente primeiro nome)  \
# 0 2021-04-30                        Gabriel                     Phillipe
# 1 2021-04-30                        Gabriel                         Dora
#
#       Bairro  Pedido Art.Smash  Pedido Art.Cheese  Pedido Art.Linguiça  \
# 0  Esplanada               NaN                3.0                  NaN
# 1   Alvorada               NaN                NaN                  NaN
#
#    Pedido Art.Frango  Pedido Art.Bacon  Pedido Art.Special  ...  \
# 0                NaN               NaN                 NaN  ...
# 1                NaN               NaN                 NaN  ...
#
#    Pedido Pastel G  Pedido Porçãao de Batata  Pedido Milkshake Chocolate  \
# 0              NaN                       1.0                         NaN
# 1              1.0                       NaN                         NaN
#
#    Pedido Milkshake Morango  Pedido Refri 200ml  Pedido Refri Lata  \
# 0                       NaN                 3.0                NaN
# 1                       NaN                 NaN                NaN
#
#    Forma de Pagamento  Valor do pedido ( somente numeros )  \
# 0               PIX 🔑                                   63
# 1          Dinheiro 💵                                   10
#
#   Taxa de Entrega (Somente Numeros, Se não tiver taxa, digite zero)  \
# 0                                                  3
# 1                                                  0
#
#    Observação
# 0         NaN
# 1         NaN
#
# [2 rows x 22 columns]
#         Data Quem preenche este formulário? Nome (somente primeiro nome)  \
# 0 2021-04-30                        Gabriel                     Phillipe
# 1 2021-04-30                        Gabriel                         Dora
#
#       Bairro  Art.Smash  Art.Cheese  Art.Linguiça  Art.Frango  Art.Bacon  \
# 0  Esplanada        NaN         3.0           NaN         NaN        NaN
# 1   Alvorada        NaN         NaN           NaN         NaN        NaN
#
#    Art.Special  ...  Pastel G  Porçãao de Batata  Milkshake Chocolate  \
# 0          NaN  ...       NaN                1.0                  NaN
# 1          NaN  ...       1.0                NaN                  NaN
#
#    Milkshake Morango  Refri 200ml  Refri Lata  Forma de Pagamento  \
# 0                NaN          3.0         NaN               PIX 🔑
# 1                NaN          NaN         NaN          Dinheiro 💵
#
#    Valor do pedido ( somente numeros )  \
# 0                                   63
# 1                                   10
#
#   Taxa de Entrega (Somente Numeros, Se não tiver taxa, digite zero)  \
# 0                                                  3
# 1                                                  0
#
#    Observação
# 0         NaN
# 1         NaN
#
# [2 rows x 22 columns]

# %%
display(dados['Platform'].value_counts())
display(dados['Forma de Pa'].value_counts(normalize=True).map('{:.1%}'.format))
